# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns = ['EIN', 'NAME'], inplace = True)

# %%
# Determine the number of unique values in each column.
for column in application_df.columns:
    unique_values = application_df[column].nunique()
    print(f'The column {column} has {unique_values} unique values.')
# Out:
# The column APPLICATION_TYPE has 17 unique values.
# The column AFFILIATION has 6 unique values.
# The column CLASSIFICATION has 71 unique values.
# The column USE_CASE has 5 unique values.
# The column ORGANIZATION has 4 unique values.
# The column STATUS has 2 unique values.
# The column INCOME_AMT has 9 unique values.
# The column SPECIAL_CONSIDERATIONS has 2 unique values.
# The column ASK_AMT has 8747 unique values.
# The column IS_SUCCESSFUL has 2 unique values.

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
print(application_type_counts)
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
cutoff_value = 100

application_types_to_replace = application_type_counts[application_type_counts < cutoff_value].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
print(classification_counts)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts[application_df['CLASSIFICATION'].value_counts() > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
cutoff_value = 100

# You may find it helpful to look at CLASSIFICATION value counts >1
cutoff_counts = classification_counts[application_df['CLASSIFICATION'].value_counts() <= cutoff_value]

print(cutoff_counts)
# Out:
# Series([], Name: CLASSIFICATION, dtype: int64)

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#cutoff_value = 100

classifications_to_replace = cutoff_counts.index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
one_hot_encoded_df = pd.get_dummies(application_df)

one_hot_encoded_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
y= one_hot_encoded_df["IS_SUCCESSFUL"].copy()
X= one_hot_encoded_df.drop(columns=["IS_SUCCESSFUL"])

# Split the preprocessed data into a training and testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=64)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=120, activation="relu", input_dim=X_train.shape[1]))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 120)               6120
#
#  dense_13 (Dense)            (None, 30)                3630
#
#  dense_14 (Dense)            (None, 1)                 31
#
# ...
# Total params: 9781 (38.21 KB)
# Trainable params: 9781 (38.21 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=300)
# Out:
# Epoch 1/300
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5261 - accuracy: 0.7427
# Epoch 2/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5264 - accuracy: 0.7430
# Epoch 3/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5265 - accuracy: 0.7428
# Epoch 4/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5269 - accuracy: 0.7421
# Epoch 5/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5263 - accuracy: 0.7428
# Epoch 6/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5287 - accuracy: 0.7427
# Epoch 7/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5267 - accuracy: 0.7425
# Epoch 8/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5264 - accuracy: 0.7428
# Epoch 9/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5262 - accuracy: 0.7425
# Epoch 10/300
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5882 - accuracy: 0.7290 - 334ms/epoch - 1ms/step
# Loss: 0.5882247686386108, Accuracy: 0.7289795875549316

# %%
# Export our model to HDF5 file
#from tensorflow.keras.models import load_model, save_model
#save_model(fit_model, 'AlphabetSoupCharity.h5')


import os

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Create a folder in the root directory
# !mkdir -p "/content/drive/My Drive/Colab Notebooks"

nn_model.save('/content/drive/My Drive/Colab Notebooks/AlphabetSoupCharity3.h5')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
